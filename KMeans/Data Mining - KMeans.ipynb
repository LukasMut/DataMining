# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import random 
import os

from clustering import *

# %%
PATH = os.path.join(os.getcwd(), 'data\\')

# %%
df = pd.read_csv(PATH + 'geyserData.csv')

# %%
normalized_data = normalize_data(df, 'standardize')

# %%
kmeans = KMeans(init='random')
data, mean_1_optim, mean_2_optim = kmeans.fit_predict(normalized_data, epochs = 10)
# Out:
# 167 points moved this round. Optimization continues.
# 5 points moved this round. Optimization continues.
# 1 point moved this round. Optimization continues.
# 1 point moved this round. Optimization continues.
# 0 points moved this round. We could stop optimization, but lets also compare the centroids first.
# Algorithm needed 5 iterations until optimal mean values were found.
