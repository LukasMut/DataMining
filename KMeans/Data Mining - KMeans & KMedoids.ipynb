# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import random 
import os

from clustering import *

# %%
PATH = os.path.join(os.getcwd(), 'data\\')

# %%
df = pd.read_csv(PATH + 'geyserData.csv')

# %%
normalized_data = data_normalization(df, 'standardize')

# %%
# init k-Means
kmeans = KMeans(random_state=42,method='k-means')
# %timeit data, mean_1_optim, mean_2_optim = kmeans.fit_predict(normalized_data, epochs = 10)
# Out:
# 175 points moved this round. Optimization continues.
# 1 point moved this round. Optimization continues.
# 0 points moved this round. Optimization will stop.
#
# Algorithm needed 3 iterations until convergence.
# 1 point moved this round. Optimization continues.
# 1 point moved this round. Optimization continues.
# 0 points moved this round. Optimization will stop.
#
# Algorithm needed 3 iterations until convergence.
# 1 point moved this round. Optimization continues.
# 1 point moved this round. Optimization continues.
# 0 points moved this round. Optimization will stop.
#
# Algorithm needed 3 iterations until convergence.
# 1 point moved this round. Optimization continues.
# 1 point moved this round. Optimization continues.
# 0 points moved this round. Optimization will stop.
#
# Algorithm needed 3 iterations until convergence.
# 1 point moved this round. Optimization continues.
# 1 point moved this round. Optimization continues.
# 0 points moved this round. Optimization will stop.
# ...

# %%
# init k-Medoids
kmedoids = KMeans(random_state=42,method='k-medoids')
# %timeit data, median_1_optim, median_2_optim = kmedoids.fit_predict(normalized_data, epochs = 10)
# Out:
# 1 point moved this round. Optimization continues.
# 1 point moved this round. Optimization continues.
# 1 point moved this round. Optimization continues.
# 0 points moved this round. Optimization will stop.
#
# Algorithm needed 4 iterations until convergence.
# 2 points moved this round. Optimization continues.
# 1 point moved this round. Optimization continues.
# 1 point moved this round. Optimization continues.
# 0 points moved this round. Optimization will stop.
#
# Algorithm needed 4 iterations until convergence.
# 2 points moved this round. Optimization continues.
# 1 point moved this round. Optimization continues.
# 1 point moved this round. Optimization continues.
# 0 points moved this round. Optimization will stop.
#
# Algorithm needed 4 iterations until convergence.
# 2 points moved this round. Optimization continues.
# 1 point moved this round. Optimization continues.
# 1 point moved this round. Optimization continues.
# 0 points moved this round. Optimization will stop.
#
# ...
